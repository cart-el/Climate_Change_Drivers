# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

def tool (data):
    data_dir = "C:/Users/USER/Desktop/Data Science Course/Applied Data Science 1/ASS 3/"
    file = data_dir + data
    WB_data = pd.read_excel(file, skiprows=3)
    return WB_data #, WB_data.transpose()
    # print(WB_data)
    
doc = tool("WD_data.xls")
print(doc)
# Out:
#       Country Name Country Code  \
# 0            Aruba          ABW
# 1            Aruba          ABW
# 2            Aruba          ABW
# 3            Aruba          ABW
# 4            Aruba          ABW
# ...            ...          ...
# 20211     Zimbabwe          ZWE
# 20212     Zimbabwe          ZWE
# 20213     Zimbabwe          ZWE
# 20214     Zimbabwe          ZWE
# 20215     Zimbabwe          ZWE
#
#                                           Indicator Name     Indicator Code  \
# 0               Urban population (% of total population)  SP.URB.TOTL.IN.ZS
# 1                                       Urban population        SP.URB.TOTL
# 2                     Urban population growth (annual %)        SP.URB.GROW
# 3                                      Population, total        SP.POP.TOTL
# 4                           Population growth (annual %)        SP.POP.GROW
# ...                                                  ...                ...
# ...

# %%
scope = doc[doc['Country Name'].isin(['Sub-Saharan Africa', 'Middle East & North Africa',
                                      'Europe & Central Asia','South Asia',
                                      'East Asia & Pacific'])]

CO2_emission = scope[(scope['Indicator Name'] == 'CO2 emissions (kt)')]
CO2_emission = CO2_emission.round(2)
#print(CO2_emission)
CO2_emission = CO2_emission.iloc[:, 35:64]
trans = CO2_emission.transpose()
#print(trans)
transs = trans.reset_index(inplace=True)
CO2 = trans.set_axis(["Year","East Asia & Pacific", "Europe & Central Asia", "Middle East & North Africa", 
                      "South Asia", "Sub-Saharan Africa"], axis=1, inplace=True)
#print(CO2_emission)
print(trans)
# Out:
#     Year  East Asia & Pacific  Europe & Central Asia  \
# 0   1991           4720763.25             7854524.74
# 1   1992           4894966.73             7507954.30
# 2   1993           5200003.33             7121012.75
# 3   1994           5454570.45             6745972.17
# 4   1995           5905982.09             6699309.98
# 5   1996           5985307.66             6724143.72
# 6   1997           6115154.81             6498796.80
# 7   1998           6106797.07             6497013.66
# 8   1999           6140436.45             6439302.00
# 9   2000           6453028.36             6517629.97
# 10  2001           6698018.47             6575471.85
# 11  2002           7058162.00             6587362.73
# 12  2003           7756963.98             6798985.53
# 13  2004           8586193.03             6805126.37
# 14  2005           9349823.13             6798745.08
# 15  2006          10010057.89             6920008.60
# 16  2007          10693457.64             6919938.59
# ...

# %%
#x = CO2['Years']
#y = COS['CO2 Emission']
#print(x)
#print(y)
trans.plot('Year', ['East Asia & Pacific', 'Europe & Central Asia', 'Middle East & North Africa', 'South Asia',
                   'Sub-Saharan Africa'])
plt.show()

# %%
Re_consum = scope[(scope['Indicator Name'] == 'Renewable energy consumption (% of total final energy consumption)')]
Re_consum = Re_consum.round(2)
print(Re_consum)
Re_consum = Re_consum.iloc[:, 35:60]
trans = Re_consum.transpose()
print(Re_consum)
transs = trans.reset_index(inplace=True)
Re_consum = trans.set_axis(["Year","East Asia & Pacific", "Europe & Central Asia", "Middle East & North Africa", 
                      "South Asia", "Sub-Saharan Africa"], axis=1, inplace=True)
#print(Re_consum)
print(trans)
# Out:
#                      Country Name Country Code  \
# 4840          East Asia & Pacific          EAS
# 4992        Europe & Central Asia          ECS
# 11680  Middle East & North Africa          MEA
# 15556                  South Asia          SAS
# 16544          Sub-Saharan Africa          SSF
#
#                                           Indicator Name  Indicator Code  \
# 4840   Renewable energy consumption (% of total final...  EG.FEC.RNEW.ZS
# 4992   Renewable energy consumption (% of total final...  EG.FEC.RNEW.ZS
# 11680  Renewable energy consumption (% of total final...  EG.FEC.RNEW.ZS
# 15556  Renewable energy consumption (% of total final...  EG.FEC.RNEW.ZS
# 16544  Renewable energy consumption (% of total final...  EG.FEC.RNEW.ZS
#
#        1960  1961  1962  1963  1964  1965  ...   2012   2013   2014   2015  \
# 4840    NaN   NaN   NaN   NaN   NaN   NaN  ...  12.57  12.64  13.08  13.06
# 4992    NaN   NaN   NaN   NaN   NaN   NaN  ...  11.68  12.40  12.57  13.01
# ...

# %%
trans.plot('Year', ['East Asia & Pacific', 'Europe & Central Asia', 'Middle East & North Africa', 'South Asia',
                   'Sub-Saharan Africa'])
plt.show()

# %%
AFF_GDP = scope[(scope['Indicator Name'] == 'Agriculture, forestry, and fishing, value added (% of GDP)')]
AFF_GDP = AFF_GDP.round(2)
print(AFF_GDP)
AFF_GDP = AFF_GDP.iloc[:, 37:65]
trans = AFF_GDP.transpose()
print(AFF_GDP)
transs = trans.reset_index(inplace=True)
AFF_GDP = trans.set_axis(["Year","East Asia & Pacific", "Europe & Central Asia", "Middle East & North Africa", 
                      "South Asia", "Sub-Saharan Africa"], axis=1, inplace=True)
#print(Re_consum)
print(trans)
# Out:
#                      Country Name Country Code  \
# 4799          East Asia & Pacific          EAS
# 4951        Europe & Central Asia          ECS
# 11639  Middle East & North Africa          MEA
# 15515                  South Asia          SAS
# 16503          Sub-Saharan Africa          SSF
#
#                                           Indicator Name  Indicator Code  \
# 4799   Agriculture, forestry, and fishing, value adde...  NV.AGR.TOTL.ZS
# 4951   Agriculture, forestry, and fishing, value adde...  NV.AGR.TOTL.ZS
# 11639  Agriculture, forestry, and fishing, value adde...  NV.AGR.TOTL.ZS
# 15515  Agriculture, forestry, and fishing, value adde...  NV.AGR.TOTL.ZS
# 16503  Agriculture, forestry, and fishing, value adde...  NV.AGR.TOTL.ZS
#
#         1960   1961   1962   1963   1964   1965  ...   2012   2013   2014  \
# 4799   24.03  28.72  27.99  28.05  26.91  27.35  ...   5.81   6.08   6.04
# 4951     NaN    NaN    NaN    NaN    NaN    NaN  ...   2.13   2.16   2.15
# ...

# %%
trans.plot('Year', ['East Asia & Pacific', 'Europe & Central Asia', 'Middle East & North Africa', 'South Asia',
                   'Sub-Saharan Africa'])
plt.show()

# %%
Re_consum = scope[(scope['Indicator Name'] == 'Renewable energy consumption (% of total final energy consumption)')]
Re_consum = Re_consum.round(2)
print(Re_consum)
Re_consum = Re_consum.iloc[:, 35:60]
trans = Re_consum.transpose()
print(Re_consum)
transs = trans.reset_index(inplace=True)
Re_consum = trans.set_axis(["Year","East Asia & Pacific", "Europe & Central Asia", "Middle East & North Africa", 
                      "South Asia", "Sub-Saharan Africa"], axis=1, inplace=True)
#print(Re_consum)
print(trans)
